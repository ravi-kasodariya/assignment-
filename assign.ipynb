# %% [markdown]
# <a href="https://colab.research.google.com/github/ravi-kasodariya/assignment-/blob/main/assign.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
path="/content/drive/MyDrive/database/Energy_dataset.csv"
df=pd.read_csv(path)
df.head(15)
# Out:
#     Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 0                   0.98         514.5      294.0     110.25             7.0
# 1                   0.98         514.5      294.0     110.25             7.0
# 2                   0.98         514.5      294.0     110.25             7.0
# 3                   0.98         514.5      294.0     110.25             7.0
# 4                   0.90         563.5      318.5     122.50             7.0
# 5                   0.90         563.5      318.5     122.50             7.0
# 6                   0.90         563.5      318.5     122.50             7.0
# 7                   0.90         563.5      318.5     122.50             7.0
# 8                   0.86         588.0      294.0     147.00             7.0
# 9                   0.86         588.0      294.0     147.00             7.0
# 10                  0.86         588.0      294.0     147.00             7.0
# ...
